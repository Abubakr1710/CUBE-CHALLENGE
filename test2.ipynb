# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
import matplotlib.pyplot as plt


def cube_intersection_check(x_bigCube, y_bigCube, z_bigCube, length_bigCube, x_smallCube, y_smallCube, z_smallCube, length_smallCube):

    center_bigCube = np.array([x_bigCube, y_bigCube, z_bigCube])

    #-----------------------------------------------------------------------------------------------------------------------
    # BIGGER CUBE CALCULATIONS
    # ------------------------------------------------------------------------------------------------------------------------
    point_A_bigCube = np.array([x_bigCube - (length_bigCube/2),     y_bigCube - (length_bigCube/2),     z_bigCube - (length_bigCube/2)])
    point_B_bigCube = np.array([x_bigCube + (length_bigCube/2),     y_bigCube - (length_bigCube/2),     z_bigCube - (length_bigCube/2)])
    point_C_bigCube = np.array([x_bigCube + (length_bigCube/2),     y_bigCube + (length_bigCube/2),     z_bigCube - (length_bigCube/2)])
    point_D_bigCube = np.array([x_bigCube - (length_bigCube/2),     y_bigCube - (length_bigCube/2),     z_bigCube - (length_bigCube/2)])
    point_E_bigCube = np.array([x_bigCube - (length_bigCube/2),     y_bigCube - (length_bigCube/2),     z_bigCube + (length_bigCube/2)])
    point_F_bigCube = np.array([x_bigCube + (length_bigCube/2),     y_bigCube - (length_bigCube/2),     z_bigCube + (length_bigCube/2)])
    point_G_bigCube = np.array([x_bigCube + (length_bigCube/2),     y_bigCube + (length_bigCube/2),     z_bigCube + (length_bigCube/2)])
    point_H_bigCube = np.array([x_bigCube - (length_bigCube/2),     y_bigCube - (length_bigCube/2),     z_bigCube + (length_bigCube/2)])

    x_points_bigCube = ([point_A_bigCube[0], point_B_bigCube[0], point_C_bigCube[0], point_D_bigCube[0], point_E_bigCube[0], point_F_bigCube[0], point_G_bigCube[0], point_H_bigCube[0]])
    x_min_bigCube = min(x_points_bigCube)
    x_max_bigCube = max(x_points_bigCube)

    y_points_bigCube = ([point_A_bigCube[1], point_B_bigCube[1], point_C_bigCube[1], point_D_bigCube[1], point_E_bigCube[1], point_F_bigCube[1], point_G_bigCube[1], point_H_bigCube[1]])
    y_min_bigCube = min(y_points_bigCube)
    y_max_bigCube = max(y_points_bigCube)

    z_points_bigCube = ([point_A_bigCube[2], point_B_bigCube[2], point_C_bigCube[2], point_D_bigCube[2], point_E_bigCube[2], point_F_bigCube[2], point_G_bigCube[2], point_H_bigCube[2]])
    z_min_bigCube = min(z_points_bigCube)
    z_max_bigCube = max(z_points_bigCube)
    #---------------------------------------------------------------------------------------------------------------------------------


#-----------------------------------------------------------------------------------------------------------------------
    # SMALLER CUBE CALCULATIONS
    # ------------------------------------------------------------------------------------------------------------------------
    point_A_smallCube = np.array([x_smallCube - (length_smallCube/2),     y_smallCube - (length_smallCube/2),     z_smallCube - (length_smallCube/2)])
    point_B_smallCube = np.array([x_smallCube + (length_smallCube/2),     y_smallCube - (length_smallCube/2),     z_smallCube - (length_smallCube/2)])
    point_C_smallCube = np.array([x_smallCube + (length_smallCube/2),     y_smallCube + (length_smallCube/2),     z_smallCube - (length_smallCube/2)])
    point_D_smallCube = np.array([x_smallCube - (length_smallCube/2),     y_smallCube - (length_smallCube/2),     z_smallCube - (length_smallCube/2)])
    point_E_smallCube = np.array([x_smallCube - (length_smallCube/2),     y_smallCube - (length_smallCube/2),     z_smallCube + (length_smallCube/2)])
    point_F_smallCube = np.array([x_smallCube + (length_smallCube/2),     y_smallCube - (length_smallCube/2),     z_smallCube + (length_smallCube/2)])
    point_G_smallCube = np.array([x_smallCube + (length_smallCube/2),     y_smallCube + (length_smallCube/2),     z_smallCube + (length_smallCube/2)])
    point_H_smallCube = np.array([x_smallCube - (length_smallCube/2),     y_smallCube - (length_smallCube/2),     z_smallCube + (length_smallCube/2)])

    x_points_smallCube = ([point_A_smallCube[0], point_B_smallCube[0], point_C_smallCube[0], point_D_smallCube[0], point_E_smallCube[0], point_F_smallCube[0], point_G_smallCube[0], point_H_smallCube[0]])
    x_min_smallCube = min(x_points_smallCube)
    x_max_smallCube = max(x_points_smallCube)

    y_points_smallCube = ([point_A_smallCube[1], point_B_smallCube[1], point_C_smallCube[1], point_D_smallCube[1], point_E_smallCube[1], point_F_smallCube[1], point_G_smallCube[1], point_H_smallCube[1]])
    y_min_smallCube = min(y_points_smallCube)
    y_max_smallCube = max(y_points_smallCube)

    z_points_smallCube = ([point_A_smallCube[2], point_B_smallCube[2], point_C_smallCube[2], point_D_smallCube[2], point_E_smallCube[2], point_F_smallCube[2], point_G_smallCube[2], point_H_smallCube[2]])
    z_min_smallCube = min(z_points_smallCube)
    z_max_smallCube = max(z_points_smallCube)
    #---------------------------------------------------------------------------------------------------------------------------------

    x_A_smallCube = point_A_smallCube[0]
    y_A_smallCube = point_A_smallCube[1]
    z_A_smallCube = point_A_smallCube[2]

    x_B_smallCube = point_B_smallCube[0]
    y_B_smallCube = point_B_smallCube[1]
    z_B_smallCube = point_B_smallCube[2]

    x_C_smallCube = point_C_smallCube[0]
    y_C_smallCube = point_C_smallCube[1]
    z_C_smallCube = point_C_smallCube[2]

    x_D_smallCube = point_D_smallCube[0]
    y_D_smallCube = point_D_smallCube[1]
    z_D_smallCube = point_D_smallCube[2]

    x_E_smallCube = point_E_smallCube[0]
    y_E_smallCube = point_E_smallCube[1]
    z_E_smallCube = point_E_smallCube[2]

    x_F_smallCube = point_F_smallCube[0]
    y_F_smallCube = point_F_smallCube[1]
    z_F_smallCube = point_F_smallCube[2]

    x_G_smallCube = point_G_smallCube[0]
    y_G_smallCube = point_G_smallCube[1]
    z_G_smallCube = point_G_smallCube[2]

    x_H_smallCube = point_H_smallCube[0]
    y_H_smallCube = point_H_smallCube[1]
    z_H_smallCube = point_H_smallCube[2]

    result = bool()

    if (((x_A_smallCube > x_min_bigCube) and ( x_max_bigCube > x_A_smallCube)) and ((y_A_smallCube > y_min_bigCube) and ( y_max_bigCube > y_A_smallCube)) and ((z_A_smallCube > z_min_bigCube) and ( z_max_bigCube > z_A_smallCube)))    or         (((x_B_smallCube > x_min_bigCube) and ( x_max_bigCube > x_B_smallCube)) and ((y_B_smallCube > y_min_bigCube) and ( y_max_bigCube > y_B_smallCube)) and ((z_B_smallCube > z_min_bigCube) and ( z_max_bigCube > z_B_smallCube))) or         (((x_C_smallCube > x_min_bigCube) and ( x_max_bigCube > x_C_smallCube)) and ((y_C_smallCube > y_min_bigCube) and ( y_max_bigCube > y_C_smallCube)) and ((z_C_smallCube > z_min_bigCube) and ( z_max_bigCube > z_C_smallCube))) or         (((x_D_smallCube > x_min_bigCube) and ( x_max_bigCube > x_D_smallCube)) and ((y_D_smallCube > y_min_bigCube) and ( y_max_bigCube > y_D_smallCube)) and ((z_D_smallCube > z_min_bigCube) and ( z_max_bigCube > z_D_smallCube))) or         (((x_E_smallCube > x_min_bigCube) and ( x_max_bigCube > x_E_smallCube)) and ((y_E_smallCube > y_min_bigCube) and ( y_max_bigCube > y_E_smallCube)) and ((z_E_smallCube > z_min_bigCube) and ( z_max_bigCube > z_E_smallCube))) or        (((x_F_smallCube > x_min_bigCube) and ( x_max_bigCube > x_F_smallCube)) and ((y_F_smallCube > y_min_bigCube) and ( y_max_bigCube > y_F_smallCube)) and ((z_F_smallCube > z_min_bigCube) and ( z_max_bigCube > z_F_smallCube))) or   (((x_G_smallCube > x_min_bigCube) and ( x_max_bigCube > x_G_smallCube)) and ((y_G_smallCube > y_min_bigCube) and ( y_max_bigCube > y_G_smallCube)) and ((z_G_smallCube > z_min_bigCube) and ( z_max_bigCube > z_G_smallCube))) or  (((x_H_smallCube > x_min_bigCube) and ( x_max_bigCube > x_H_smallCube)) and ((y_H_smallCube > y_min_bigCube) and ( y_max_bigCube > y_H_smallCube)) and ((z_H_smallCube > z_min_bigCube) and ( z_max_bigCube > z_H_smallCube))):
        result = [True, 'Volume =']

    else:
        # print([x_new, y_new, z_new], 'is OUTSIDE the CUBE')
        result = [False]
    
    return result

cube_intersection_check(0, 0, 0, 18, 3, 2, 2, 4)
# Out:
# [True, 'Volume =']
