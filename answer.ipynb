# %%
import numpy as np

# %%
class Cube:

    def __int__(self,x1,y1,z1,s1,x2,y2,z2,s2):
        self.x1 = x1
        self.y1 = y1
        self.z1 = z1
        self.s1 = s1
        self.x2 = x2
        self.y2 = y2
        self.z2 = z2
        self.s2 = s2

    def check(self):  

        # Cube 1 calculations
        # --------------------------------------------------------------------------------------------------------------------------------------
        pointA1 = np.array([self.x1 - (self.s1/2),   self.y1 - (self.s1/2),   self.z1 - (self.s1/2) ])
        pointB1 = np.array([self.x1 + (self.s1/2),   self.y1 - (self.s1/2),   self.z1 - (self.s1/2) ])
        pointC1 = np.array([self.x1 + (self.s1/2),   self.y1 + (self.s1/2),   self.z1 - (self.s1/2) ])
        pointD1 = np.array([self.x1 - (self.s1/2),   self.y1 - (self.s1/2),   self.z1 - (self.s1/2) ])
        pointE1 = np.array([self.x1 - (self.s1/2),   self.y1 - (self.s1/2),   self.z1 + (self.s1/2) ])
        pointF1 = np.array([self.x1 + (self.s1/2),   self.y1 - (self.s1/2),   self.z1 + (self.s1/2) ])
        pointG1 = np.array([self.x1 + (self.s1/2),   self.y1 + (self.s1/2),   self.z1 + (self.s1/2) ])
        pointH1 = np.array([self.x1 - (self.s1/2),   self.y1 - (self.s1/2),   self.z1 + (self.s1/2) ])

        x1_points = ([pointA1[0], pointB1[0], pointC1[0], pointD1[0], pointE1[0], pointF1[0], pointG1[0], pointH1[0]])
        x1_min = min(x1_points)
        x1_max = max(x1_points)

        y1_points = ([pointA1[1], pointB1[1], pointC1[1], pointD1[1], pointE1[1], pointF1[1], pointG1[1], pointH1[1]])
        y1_min = min(y1_points)
        y1_max = max(y1_points)
        
        z1_points =  ([pointA1[2], pointB1[2], pointC1[2], pointD1[2], pointE1[2], pointF1[2], pointG1[2], pointH1[2]])
        z1_min = min(z1_points)
        z1_max = max(z1_points)
        # --------------------------------------------------------------------------------------------------------------------------------------

        # Cube 2 calculations
        # --------------------------------------------------------------------------------------------------------------------------------------
        pointA2 = np.array([self.x2 - (self.s2/2),   self.y2 - (self.s2/2),   self.z2 - (self.s2/2) ])
        pointB2 = np.array([self.x2 + (self.s2/2),   self.y2 - (self.s2/2),   self.z2 - (self.s2/2) ])
        pointC2 = np.array([self.x2 + (self.s2/2),   self.y2 + (self.s2/2),   self.z2 - (self.s2/2) ])
        pointD2 = np.array([self.x2 - (self.s2/2),   self.y2 - (self.s2/2),   self.z2 - (self.s2/2) ])
        pointE2 = np.array([self.x2 - (self.s2/2),   self.y2 - (self.s2/2),   self.z2 + (self.s2/2) ])
        pointF2 = np.array([self.x2 + (self.s2/2),   self.y2 - (self.s2/2),   self.z2 + (self.s2/2) ])
        pointG2 = np.array([self.x2 + (self.s2/2),   self.y2 + (self.s2/2),   self.z2 + (self.s2/2) ])
        pointH2 = np.array([self.x2 - (self.s2/2),   self.y2 - (self.s2/2),   self.z2 + (self.s2/2) ])

        x2_points = ([pointA2[0], pointB2[0], pointC2[0], pointD2[0], pointE2[0], pointF2[0], pointG2[0], pointH2[0]])
        x2_min = min(x2_points)
        x2_max = max(x2_points)

        y2_points = ([pointA2[1], pointB2[1], pointC2[1], pointD2[1], pointE2[1], pointF2[1], pointG2[1], pointH2[1]])
        y2_min = min(y2_points)
        y2_max = max(y2_points)
        
        z2_points =  ([pointA2[2], pointB2[2], pointC2[2], pointD2[2], pointE2[2], pointF2[2], pointG2[2], pointH2[2]])
        z2_min = min(z2_points)
        z2_max = max(z2_points)
        # --------------------------------------------------------------------------------------------------------------------------------------

        x_A2 = pointA2[0]
        y_A2 = pointA2[1] 
        z_A2 = pointA2[2]

        x_B2 = pointB2[0]
        y_B2 = pointB2[1] 
        z_B2 = pointB2[2]

        x_C2 = pointC2[0]
        y_C2 = pointC2[1] 
        z_C2 = pointC2[2]

        x_D2 = pointD2[0]
        y_D2 = pointD2[1] 
        z_D2 = pointD2[2]

        x_E2 = pointE2[0]
        y_E2 = pointE2[1] 
        z_E2 = pointE2[2]

        x_F2 = pointF2[0]
        y_F2 = pointF2[1] 
        z_F2 = pointF2[2]

        x_G2 = pointG2[0]
        y_G2 = pointG2[1] 
        z_G2 = pointG2[2]

        x_H2 = pointH2[0]
        y_H2 = pointH2[1] 
        z_H2 = pointH2[2]

        result = bool()

        if (((x_A2 > x1_min) and ( x1_max > x_A2)) and ((y_A2 > y1_min) and (y1_max > y_A2)) and ((z_A2 > z1_min) and ( z1_max > z_A2)))    or         (((x_B2 > x1_min) and ( x1_max > x_B2)) and ((y_B2 > y1_min) and ( y1_max > y_B2)) and ((z_B2 > z1_min) and ( z1_max > z_B2))) or         (((x_C2 > x1_min) and ( x1_max > x_C2)) and ((y_C2 > y1_min) and ( y1_max > y_C2)) and ((z_C2 > z1_min) and ( z1_max > z_C2))) or         (((x_D2 > x1_min) and ( x1_max > x_D2)) and ((y_D2> y1_min) and ( y1_max > y_D2)) and ((z_D2 >z1_min) and ( z1_max > z_D2))) or         (((x_E2 > x1_min) and ( x1_max > x_E2)) and ((y_E2 > y1_min) and ( y1_max > y_E2)) and ((z_E2 > z1_min) and ( z1_max > z_E2))) or        (((x_F2 > x1_min) and ( x1_max > x_F2)) and ((y_F2 > y1_min) and ( y1_max > y_F2)) and ((z_F2 > z1_min) and ( z1_max > z_F2))) or   (((x_G2 > x1_min) and ( x1_max > x_G2)) and ((y_G2 > y1_min) and ( y1_max > y_G2)) and ((z_G2 > z1_min) and ( z1_max > z_G2))) or  (((x_H2 > x1_min) and ( x1_max > x_H2)) and ((y_H2 > y1_min) and ( y1_max > y_H2)) and ((z_H2 > z1_min) and ( z1_max > z_H2))):

            result = [True, 'Volume =']
        else:
            result = [False]

        return result

go=Cube(10,10,0,5,8,9,0,2)
go.check()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Abu\Documents\GitHub\CUBE-CHALLENGE\answer.ipynb Cell 2' in <module>
#     <a href='vscode-notebook-cell:/c%3A/Users/Abu/Documents/GitHub/CUBE-CHALLENGE/answer.ipynb#ch0000001?line=100'>101</a>             result = [False]
#     <a href='vscode-notebook-cell:/c%3A/Users/Abu/Documents/GitHub/CUBE-CHALLENGE/answer.ipynb#ch0000001?line=102'>103</a>         return result
# --> <a href='vscode-notebook-cell:/c%3A/Users/Abu/Documents/GitHub/CUBE-CHALLENGE/answer.ipynb#ch0000001?line=104'>105</a> go=Cube(10,10,0,5,8,9,0,2)
#     <a href='vscode-notebook-cell:/c%3A/Users/Abu/Documents/GitHub/CUBE-CHALLENGE/answer.ipynb#ch0000001?line=105'>106</a> go.check()
#
# TypeError: Cube() takes no arguments
